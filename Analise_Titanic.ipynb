# %% [markdown]
# <a href="https://colab.research.google.com/github/Emanuelnabarrete/Titanic_Analise/blob/main/Analise_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando dados

# %%
import pandas as pd

# %%
dados = pd.read_csv("Titanic-Dataset.csv")# Importando dataset

# %% [markdown]
# ----->Numero de sobreviventes
# ---->Relacao de sexo
# ---->classe

# %%
dados
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dados.fillna(0, inplace = True)

# %% [markdown]
# # Tratando Dados

# %%
dados
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dados.Embarked.fillna(0, inplace= True)

# %%
dados[dados.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
dados.fillna(0, inplace = True)

# %%
dados[dados.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dados.Survived.replace([0,1] , ["No" , "Yes"] , inplace = True)

# %%
dados.drop(columns = "PassengerId", inplace  = True)

# %%
dados.drop(columns = "Cabin", inplace  = True)

# %%
dados
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# ------------------------------- Dados Tratatos ----------------------------------

# %% [markdown]
# # Analisando Dados

# %%
# --------------------------------- Trazendo Insights -------------------------------

# %%
subreviventes = dados.Survived.value_counts(normalize = True)

# %%
# !pip install plotly

# %%
# !pip install matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
px.histogram(dados, x = "Sex" , color = "Survived", text_auto = True)# por sexo
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(dados, x = "Embarked" , color = "Survived" , text_auto = True)# Classe
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.catplot( x = "Survived" , kind = "count" ,data = dados , ) #total

# %%
round(dados[["Age" ,"Fare" ]].median(),2)
# Out:
# Age     24.00
# Fare    14.45
# dtype: float64

# %%
dados.Survived.value_counts(normalize= False )
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
233 + 81 # women
# Out:
# 314

# %%
468 + 109 #men
# Out:
# 577

# %%
round((314/577)*100 , 2)
# Out:
# 54.42

# %%
h = 468
m = 81

# %%
cal_sexo = (h - m) / m * 100

# %%
cal_sexo
# Out:
# 477.77777777777777

# %%
dados["Parch"].sum()
# Out:
# 340
